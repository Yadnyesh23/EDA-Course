# %% [markdown]
# # NumPy Practice — California Housing Dataset
#
# Dataset: `housing.csv` (place it in the same folder as this notebook).
#
# Each district (row) in this dataset represents a block group in California with housing and demographic stats. Work with the data as NumPy arrays (not Pandas) for every question below. Write your solution in the empty cell placed right below each question.

# %% [markdown]
# ## Setup — load the data

# %%
import numpy as np

# Load only the numeric columns into a NumPy array
# columns: longitude, latitude, housing_median_age, total_rooms, total_bedrooms,
#          population, households, median_income, median_house_value
data = np.genfromtxt('housing.csv', delimiter=',', skip_header=1, usecols=range(9))

columns = ['longitude', 'latitude', 'housing_median_age', 'total_rooms', 'total_bedrooms',
           'population', 'households', 'median_income', 'median_house_value']

data.shape

# %% [markdown]
# ### Q1
# How many districts (rows) and how many features (columns) does this dataset have?

# %% [markdown]
# ### Q2
# What is the average median house value across all districts?

# %% [markdown]
# ### Q3
# What is the median housing age across all districts?

# %% [markdown]
# ### Q4
# What is the standard deviation of the median income column?

# %% [markdown]
# ### Q5
# Find the highest median house value in the dataset, and which row (district) it belongs to.

# %% [markdown]
# ### Q6
# Find the district with the lowest population, and print its full row of data.

# %% [markdown]
# ### Q7
# How many districts have missing values in the total_bedrooms column?

# %% [markdown]
# ### Q8
# Replace the missing values in total_bedrooms with the average of that column.

# %% [markdown]
# ### Q9
# How many districts have a median house value greater than 500,000?

# %% [markdown]
# ### Q10
# What is the average number of rooms per household across the dataset? (rooms per household = total_rooms / households)

# %% [markdown]
# ### Q11
# How strongly are median income and median house value related to each other?

# %% [markdown]
# ### Q12
# Find the 5 districts with the highest median income.

# %% [markdown]
# ### Q13
# Scale the median house value column so that all its values fall between 0 and 1.

# %% [markdown]
# ### Q14
# How many districts have a housing median age between 20 and 30 (inclusive)?

# %% [markdown]
# ### Q15
# Pick 10 random districts from the dataset and show their median house values.

# %% [markdown]
# ### Q16
# Split the population column into 5 equal-width groups and find how many districts fall into each group.

# %% [markdown]
# ### Q17
# Sort the districts by median house value from highest to lowest, and show the top 10.
