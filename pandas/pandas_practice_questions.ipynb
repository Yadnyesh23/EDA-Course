# %% [markdown]
# # Pandas Practice — IPL Matches Dataset
#
# Dataset: `ipl_matches.csv` (place it in the same folder as this notebook).
#
# This dataset contains every IPL match from 2008 onward, with details like season, teams, toss, venue, winner, and margin of victory. Write your solution in the empty cell placed right below each question.

# %% [markdown]
# ## Setup — load the data

# %%
import pandas as pd

df = pd.read_csv('ipl_matches.csv')
df.head(5)
# Out:
#    id  season        city        date                  team1  \
# 0   1    2008   Bangalore  2008-04-18  Kolkata Knight Riders
# 1   2    2008  Chandigarh  2008-04-19    Chennai Super Kings
# 2   3    2008       Delhi  2008-04-19       Rajasthan Royals
# 3   4    2008      Mumbai  2008-04-20         Mumbai Indians
# 4   5    2008     Kolkata  2008-04-20        Deccan Chargers
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1              Kings XI Punjab          Chennai Super Kings           bat
# 2             Delhi Daredevils             Rajasthan Royals           bat
# 3  Royal Challengers Bangalore               Mumbai Indians           bat
# 4        Kolkata Knight Riders              Deccan Chargers           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# 0  normal           0        Kolkata Knight Riders          140
# ...

# %% [markdown]
# ### Q1
# How many matches are there in the dataset in total?

# %% [markdown]
# ### Q2
# How many different seasons are covered in this dataset?

# %% [markdown]
# ### Q3
# How many matches were played in each season?

# %% [markdown]
# ### Q4
# Which team has won the most matches overall?

# %% [markdown]
# ### Q5
# Which venue has hosted the most matches?

# %% [markdown]
# ### Q6
# In how many matches did the toss-winning team also go on to win the match?

# %% [markdown]
# ### Q7
# List all the matches that were played in Mumbai.

# %% [markdown]
# ### Q8
# Which player has won the most 'Player of the Match' awards?

# %% [markdown]
# ### Q9
# Find all matches where the winning team won by more than 100 runs.

# %% [markdown]
# ### Q10
# How many matches were affected by the Duckworth-Lewis (D/L) method?

# %% [markdown]
# ### Q11
# What is the average winning margin (in runs) for matches that were decided by runs rather than wickets?

# %% [markdown]
# ### Q12
# Which city has hosted matches across the most number of different seasons?

# %% [markdown]
# ### Q13
# For each team, calculate how many matches they won out of the total matches they played, and find which team has the best win rate.

# %% [markdown]
# ### Q14
# How many missing values are there in each column of the dataset?

# %% [markdown]
# ### Q15
# Find all matches from the 2016 season where Mumbai Indians played (either as team1 or team2).

# %% [markdown]
# ### Q16
# Combine umpire1 and umpire2 into one list and find which umpire has officiated the most matches.

# %% [markdown]
# ### Q17
# Add a new column that shows the match result margin type (whether it was won by runs or by wickets), then count how many matches fall into each type.
